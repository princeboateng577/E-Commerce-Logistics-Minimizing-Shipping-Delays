# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load raw data
file_path = "../Data/Cleaned/income2024_cleaned.csv"

data_log_1 = pd.read_csv(file_path)
display(data_log_1.head())
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city  customer_id customer_segment  \
# 0      Cardio Equipment        Caguas   12097.6830         Consumer
# 1          Water Sports   Albuquerque    5108.1045         Consumer
# 2  Indoor/Outdoor Games      Amarillo    4293.4478         Consumer
# 3                Cleats        Caguas     546.5306         Consumer
# 4          Water Sports       Peabody    1546.3980         Consumer
#
#    customer_zipcode  department_id  ... product_category_id  \
# 0          725.0000            3.0  ...                 9.0
# 1        92745.1600            7.0  ...                48.0
# 2         2457.7297            7.0  ...                46.0
# 3          725.0000            4.0  ...                17.0
# 4        95118.6000            7.0  ...                48.0
#
#                         product_name  product_price  \
# 0  Nike Men's Free 5.0+ Running Shoe          99.99
# 1        Pelican Sunstream 100 Kayak         199.99
# 2   O'Brien Men's Neoprene Life Vest          49.98
# 3   Perfect Fitness Perfect Rip Deck          59.99
# 4        Pelican Sunstream 100 Kayak         199.99
#
#                shipping_date   shipping_mode label  shipping_time  \
# 0  2015-08-12 23:00:00+00:00  Standard Class    -1       23:00:00
# 1  2017-04-08 23:00:00+00:00  Standard Class    -1       23:00:00
# 2  2015-03-18 00:00:00+00:00    Second Class     1       00:00:00
# 3  2017-03-18 00:00:00+00:00    Second Class     0       00:00:00
# 4  2015-03-29 23:00:00+00:00  Standard Class     1       23:00:00
#
#   shipping_date_only  order_time  order_date_only
# 0         2015-08-12    23:00:00       2015-08-11
# 1         2017-04-08    00:00:00       2017-02-10
# 2         2015-03-18    00:00:00       2015-01-01
# 3         2017-03-18    23:00:00       2017-05-30
# 4         2015-03-29    00:00:00       2015-03-28
#
# [5 rows x 41 columns]

# %%
#Drop specific columns : The customer_
data_log_2 = data_log_1.drop(columns=["shipping_daet", "oder_date"], errors ='ignore')
display(data_log_2.head())
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city  customer_id customer_segment  \
# 0      Cardio Equipment        Caguas   12097.6830         Consumer
# 1          Water Sports   Albuquerque    5108.1045         Consumer
# 2  Indoor/Outdoor Games      Amarillo    4293.4478         Consumer
# 3                Cleats        Caguas     546.5306         Consumer
# 4          Water Sports       Peabody    1546.3980         Consumer
#
#    customer_zipcode  department_id  ... product_category_id  \
# 0          725.0000            3.0  ...                 9.0
# 1        92745.1600            7.0  ...                48.0
# 2         2457.7297            7.0  ...                46.0
# 3          725.0000            4.0  ...                17.0
# 4        95118.6000            7.0  ...                48.0
#
#                         product_name  product_price  \
# 0  Nike Men's Free 5.0+ Running Shoe          99.99
# 1        Pelican Sunstream 100 Kayak         199.99
# 2   O'Brien Men's Neoprene Life Vest          49.98
# 3   Perfect Fitness Perfect Rip Deck          59.99
# 4        Pelican Sunstream 100 Kayak         199.99
#
#                shipping_date   shipping_mode label  shipping_time  \
# 0  2015-08-12 23:00:00+00:00  Standard Class    -1       23:00:00
# 1  2017-04-08 23:00:00+00:00  Standard Class    -1       23:00:00
# 2  2015-03-18 00:00:00+00:00    Second Class     1       00:00:00
# 3  2017-03-18 00:00:00+00:00    Second Class     0       00:00:00
# 4  2015-03-29 23:00:00+00:00  Standard Class     1       23:00:00
#
#   shipping_date_only  order_time  order_date_only
# 0         2015-08-12    23:00:00       2015-08-11
# 1         2017-04-08    00:00:00       2017-02-10
# 2         2015-03-18    00:00:00       2015-01-01
# 3         2017-03-18    23:00:00       2017-05-30
# 4         2015-03-29    00:00:00       2015-03-28
#
# [5 rows x 41 columns]

# %%
#Separate numerical and categorical columns
num_cols = data_log_2.select_dtypes(include=['float64', 'int64']).columns
cat_cols = data_log_2.select_dtypes(include=['object']).columns

# %%
# Summary statistics for numerical data
print("\nSummary statistics for numerical data: ")
display(data_log_2[num_cols].describe())
# Out:
# Summary statistics for numerical data:
#        profit_per_order  sales_per_customer   category_id   customer_id  \
# count      15549.000000        15549.000000  15549.000000  15549.000000
# mean          22.604542          179.888256     31.461342   6583.279789
# std           99.265198          113.727323     15.303616   4114.273782
# min        -3442.500000            8.351162      2.000000      1.000000
# 25%            7.562795          104.397330     18.000000   3119.983200
# 50%           31.693370          165.944170     29.000000   6429.229000
# 75%           63.872166          242.440930     45.000000   9642.381000
# max          911.800000         1939.990000     76.000000  20757.000000
#
#        customer_zipcode  department_id      latitude     longitude  \
# count      15549.000000   15549.000000  15549.000000  15549.000000
# mean       35458.234968       5.413462     29.677619    -84.512318
# std        37343.702033       1.581550      9.877876     20.681015
# min          603.000000       2.000000    -33.937553   -158.025990
# 25%          725.000000       4.000000     18.263327    -98.088170
# 50%        19145.775000       5.000000     33.435677    -76.580800
# 75%        77502.820000       7.000000     39.277313    -66.370575
# max        99205.000000      12.000000     48.781933    115.263080
#
#        order_customer_id      order_id  ...  order_item_product_price  \
# count       15549.000000  15549.000000  ...              15549.000000
# mean         6586.810354  35718.970019  ...                137.005272
# std          4101.324290  21071.742668  ...                134.545269
# min             1.000000      1.000000  ...                  9.990000
# 25%          3177.568800  16530.752000  ...                 50.000000
# 50%          6308.530000  35391.336000  ...                 59.990000
# 75%          9703.070000  55236.910000  ...                199.990000
# max         20757.000000  77204.000000  ...               1999.990000
#
#        order_item_profit_ratio  order_item_quantity         sales  \
# count             15549.000000         15549.000000  15549.000000
# mean                  0.120391             2.165202    200.562289
# std                   0.474088             1.468627    125.984986
# min                  -2.750000             1.000000      9.990000
# 25%                   0.080000             1.000000    119.980000
# 50%                   0.270000             1.000000    199.920000
# 75%                   0.360000             3.000000    299.950000
# max                   0.500000             5.000000   1999.990000
#
#        order_item_total_amount  order_profit_per_order  product_card_id  \
# count             15549.000000            15549.000000     15549.000000
# mean                179.780850               22.273342       685.213286
# std                 110.999735              117.503163       330.778230
# min                   7.490000            -3442.500000        19.000000
# 25%                 105.570910                7.443977       403.000000
# 50%                 165.990000               32.440100       627.000000
# 75%                 242.436400               64.303566      1004.000000
# max                1939.990000              911.800000      1363.000000
#
#        product_category_id  product_price         label
# count         15549.000000   15549.000000  15549.000000
# mean             31.387606     136.629368      0.349283
# std              15.256620     133.366285      0.826623
# min               2.000000       9.990000     -1.000000
# 25%              18.000000      50.000000      0.000000
# 50%              29.000000      59.990000      1.000000
# 75%              45.000000     199.990000      1.000000
# max              76.000000    1999.990000      1.000000
#
# [8 rows x 24 columns]

# %%
#Value counts for categorical data
print("\nValue counts for categorical data: ")
for col in cat_cols: 
    print(f"\n{col}:\n", data_log_2[col].value_counts())
# Out:
# Value counts for categorical data:
#
# payment_type:
#  payment_type
# DEBIT       6148
# PAYMENT     3849
# TRANSFER    3796
# CASH        1756
# Name: count, dtype: int64
#
# category_name:
#  category_name
# Cleats                  2212
# Men's Footwear          1931
# Women's Apparel         1906
# Indoor/Outdoor Games    1657
# Fishing                 1426
# Water Sports            1391
# Camping & Hiking        1127
# Shop By Sport           1056
# Cardio Equipment        1049
# Electronics              219
# Accessories              123
# Golf Balls               120
# Golf Gloves              101
# Girls' Apparel            76
# Crafts                    63
# Video Games               63
# Children's Clothing       59
# Trade-In                  58
# Cameras                   57
# Music                     55
# Women's Clothing          52
# Golf Shoes                52
# Baseball & Softball       51
# Pet Supplies              46
# Hockey                    44
# Hunting & Shooting        42
# Toys                      38
# Lacrosse                  37
# Boxing & MMA              33
# Garden                    33
# DVDs                      32
# Soccer                    29
# Tennis & Racquet          29
# Books                     28
# Fitness Accessories       27
# Baby                      27
# Consumer Electronics      23
# Health and Beauty         22
# CDs                       21
# Computers                 21
# As Seen on  TV!           19
# Men's Clothing            19
# Golf Apparel              16
# Sporting Goods            16
# Men's Golf Clubs          12
# Basketball                10
# Kids' Golf Clubs           9
# Strength Training          6
# Women's Golf Clubs         6
# Name: count, dtype: int64
#
# customer_city:
#  customer_city
# Caguas         5964
# Brooklyn        300
# Chicago         277
# Los Angeles     259
# Bronx           147
#                ...
# Irwin             1
# Upland            1
# Alhambra          1
# Everett           1
# Folsom            1
# Name: count, Length: 555, dtype: int64
#
# customer_segment:
#  customer_segment
# Consumer       8332
# Corporate      4603
# Home Office    2614
# Name: count, dtype: int64
#
# department_name:
#  department_name
# Fan Shop              5708
# Apparel               4273
# Golf                  3064
# Footwear              1208
# Outdoors               778
# Fitness                179
# Discs Shop             163
# Technology              94
# Pet Shop                31
# Book Shop               26
# Health and Beauty       25
# Name: count, dtype: int64
#
# market:
#  market
# Europe          4578
# LATAM           4414
# Pacific Asia    3518
# USCA            2125
# Africa           914
# Name: count, dtype: int64
#
# order_city:
#  order_city
# Santo Domingo          214
# New York City          194
# Managua                167
# Tegucigalpa            167
# Manila                 140
#                       ...
# Edinburg                 1
# Cruzeiro                 1
# Gorzow Wielkopolski      1
# Vertou                   1
# Asti                     1
# Name: count, Length: 2742, dtype: int64
#
# order_country:
#  order_country
# United States            2048
# Mexico                   1252
# France                   1215
# Australia                 812
# Germany                   809
#                          ...
# Cyprus                      1
# Republic of the Congo       1
# Syria                       1
# Ethiopia                    1
# United Arab Emirates        1
# Name: count, Length: 152, dtype: int64
#
# order_date:
#  order_date
# 2017-04-21 23:00:00+00:00    43
# 2015-01-01 00:00:00+00:00    41
# 2016-06-25 23:00:00+00:00    36
# 2015-07-07 23:00:00+00:00    35
# 2016-05-12 23:00:00+00:00    34
#                              ..
# 2018-11-21 00:00:00+00:00     1
# 2018-10-27 23:00:00+00:00     1
# 2018-10-15 23:00:00+00:00     1
# 2018-04-24 23:00:00+00:00     1
# 2018-09-22 23:00:00+00:00     1
# Name: count, Length: 1162, dtype: int64
#
# order_status:
#  order_status
# COMPLETE           5290
# PENDING_PAYMENT    3826
# PROCESSING         2046
# PENDING            1807
# CLOSED             1763
# ON_HOLD             761
# PAYMENT_REVIEW       56
# Name: count, dtype: int64
#
# product_name:
#  product_name
# Perfect Fitness Perfect Rip Deck             2219
# Nike Men's CJ Elite 2 TD Football Cleat      1916
# Nike Men's Dri-FIT Victory Golf Polo         1886
# O'Brien Men's Neoprene Life Vest             1653
# Field & Stream Sportsman 16 Gun Fire Safe    1436
#                                              ...
# Garmin Forerunner 910XT GPS Watch               2
# Nike Men's Free TR 5.0 TB Training Shoe         1
# SOLE E35 Elliptical                             1
# Brooks Women's Ghost 6 Running Shoe             1
# Titleist Club Glove Travel Cover                1
# Name: count, Length: 113, dtype: int64
#
# shipping_date:
#  shipping_date
# 2015-05-19 23:00:00+00:00    52
# 2017-05-05 23:00:00+00:00    47
# 2016-08-17 23:00:00+00:00    43
# 2016-04-26 23:00:00+00:00    35
# 2017-05-01 23:00:00+00:00    34
#                              ..
# 2018-02-09 00:00:00+00:00     1
# 2018-06-03 23:00:00+00:00     1
# 2018-04-13 23:00:00+00:00     1
# 2018-01-03 00:00:00+00:00     1
# 2018-02-16 00:00:00+00:00     1
# Name: count, Length: 1170, dtype: int64
#
# shipping_mode:
#  shipping_mode
# Standard Class    9116
# Second Class      3283
# First Class       2391
# Same Day           759
# Name: count, dtype: int64
#
# shipping_time:
#  shipping_time
# 23:00:00    10095
# 00:00:00     5454
# Name: count, dtype: int64
#
# shipping_date_only:
#  shipping_date_only
# 2015-05-19    52
# 2017-05-05    47
# 2016-08-17    43
# 2016-04-26    35
# 2015-03-29    35
#               ..
# 2018-11-03     1
# 2018-08-30     1
# 2018-07-14     1
# 2018-10-25     1
# 2018-02-16     1
# Name: count, Length: 1167, dtype: int64
#
# order_time:
#  order_time
# 23:00:00    10128
# 00:00:00     5421
# Name: count, dtype: int64
#
# order_date_only:
#  order_date_only
# 2017-04-21    43
# 2017-03-26    42
# 2015-01-01    41
# 2016-06-25    36
# 2015-07-07    35
#               ..
# 2018-11-21     1
# 2018-10-27     1
# 2018-10-15     1
# 2018-04-24     1
# 2018-09-22     1
# Name: count, Length: 1159, dtype: int64

# %%
# Histogram for numerical features
# Histograms for numerical features
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(data_log_1[col], bins=30, kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
#Boxplots for numerical features: check for outliers
for col in num_cols:
    plt.figure9figsize=(10, 6)
    sns.boxplot(x=data_log_1[col])
    plt.title(f"{col}")
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(10, 5))
    data_log_1[col].value_counts().nlargest(10).plot(kind='bar', color='skyblue')
    plt.title(f"{col}")
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
