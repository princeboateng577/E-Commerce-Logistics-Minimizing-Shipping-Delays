# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load raw data
file_path = "../Data/raw/incom2024_delay_example_dataset.csv"

data_log = pd.read_csv(file_path)
display(data_log.head())
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city customer_country  customer_id  \
# 0      Cardio Equipment        Caguas      Puerto Rico   12097.6830
# 1          Water Sports   Albuquerque          EE. UU.    5108.1045
# 2  Indoor/Outdoor Games      Amarillo      Puerto Rico    4293.4478
# 3                Cleats        Caguas      Puerto Rico     546.5306
# 4          Water Sports       Peabody          EE. UU.    1546.3980
#
#   customer_segment customer_state  customer_zipcode  department_id  \
# 0         Consumer             PR          725.0000            3.0
# 1         Consumer             CA        92745.1600            7.0
# 2         Consumer             PR         2457.7297            7.0
# 3         Consumer             PR          725.0000            4.0
# 4         Consumer             CA        95118.6000            7.0
#
#   department_name   latitude   longitude  market    order_city order_country  \
# 0        Footwear  18.359064  -66.370575  Europe         Viena       Austria
# 1        Fan Shop  37.636528 -121.119630   LATAM  Buenos Aires     Argentina
# 2        Fan Shop  18.294100  -66.037056  Europe        Burnie        France
# 3         Apparel  18.202435  -66.370510   LATAM     Santa Ana   El Salvador
# 4        Fan Shop  38.719500 -122.319720   LATAM      Blumenau        Mexico
#
#    order_customer_id                 order_date    order_id  \
# 0        12073.33600  2015-08-12 00:00:00+01:00  15081.2890
# 1         5111.04800  2017-02-10 00:00:00+00:00  56444.6840
# 2         4134.76500  2015-01-01 00:00:00+00:00   7508.5713
# 3          495.18726  2017-05-31 00:00:00+01:00  56196.9260
# 4         1758.91190  2015-03-28 00:00:00+00:00   5565.5796
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                   191.0            12.623338                      0.13
# 1                  1073.0            16.500000                      0.07
# 2                  1014.0             6.600000                      0.06
# 3                   365.0            16.942171                      0.16
# 4                  1073.0            29.990000                      0.15
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0      38030.996                     99.99                     0.41
# 1     142621.780                    199.99                     0.48
# 2      18723.178                     49.98                     0.09
# 3     141654.580                     59.99                    -0.80
# 4      14204.896                    199.99                     0.27
#
#    order_item_quantity   sales  order_item_total_amount  \
# 0                  1.0   99.99                 84.99157
# 1                  1.0  199.99                181.99000
# 2                  2.0   99.96                 93.81015
# 3                  2.0  119.98                 99.89060
# 4                  1.0  199.99                171.07587
#
#    order_profit_per_order     order_region                 order_state  \
# 0               32.083145   Western Europe                      Vienna
# 1               91.235870    South America                Buenos Aires
# 2                6.965549   Western Europe  Nord-Pas-de-Calais-Picardy
# 3              -95.401400  Central America                   Santa Ana
# 4               44.569000  Central America                    Illinois
#
#   order_status  product_card_id  product_category_id  \
# 0     COMPLETE            191.0                  9.0
# 1      PENDING           1073.0                 48.0
# 2     COMPLETE           1014.0                 46.0
# 3   PROCESSING            365.0                 17.0
# 4     COMPLETE           1073.0                 48.0
#
#                         product_name  product_price  \
# 0  Nike Men's Free 5.0+ Running Shoe          99.99
# 1        Pelican Sunstream 100 Kayak         199.99
# 2   O'Brien Men's Neoprene Life Vest          49.98
# 3   Perfect Fitness Perfect Rip Deck          59.99
# 4        Pelican Sunstream 100 Kayak         199.99
#
#                shipping_date   shipping_mode  label
# 0  2015-08-13 00:00:00+01:00  Standard Class     -1
# 1  2017-04-09 00:00:00+01:00  Standard Class     -1
# 2  2015-03-18 00:00:00+00:00    Second Class      1
# 3  2017-03-18 00:00:00+00:00    Second Class      0
# 4  2015-03-30 00:00:00+01:00  Standard Class      1

# %%
#Check for null values
#data_log.isnull() #This returns a Dataframe with false values indicating that there are no missing or null values
#data_log.isna().any()   # We use this to check for null values in each of the columns
#daat_lo.isna().sum()  #We use this to estimate the number of null values in each column

# %%
#Checking for duplicate columns
#data_log.duplicated()

# %%
# data_log.set_option('display.max_row', None)
#pd.set_option('display.max_columns',None)
#display(data_log)

# %%
#Drop specific columns : The customer_
data_log_1 = data_log.drop(columns=["customer_country", "customer_state", "order_state", "order_region"], errors ='ignore')
display(data_log_1.head())
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city  customer_id customer_segment  \
# 0      Cardio Equipment        Caguas   12097.6830         Consumer
# 1          Water Sports   Albuquerque    5108.1045         Consumer
# 2  Indoor/Outdoor Games      Amarillo    4293.4478         Consumer
# 3                Cleats        Caguas     546.5306         Consumer
# 4          Water Sports       Peabody    1546.3980         Consumer
#
#    customer_zipcode  department_id department_name   latitude   longitude  \
# 0          725.0000            3.0        Footwear  18.359064  -66.370575
# 1        92745.1600            7.0        Fan Shop  37.636528 -121.119630
# 2         2457.7297            7.0        Fan Shop  18.294100  -66.037056
# 3          725.0000            4.0         Apparel  18.202435  -66.370510
# 4        95118.6000            7.0        Fan Shop  38.719500 -122.319720
#
#    market    order_city order_country  order_customer_id  \
# 0  Europe         Viena       Austria        12073.33600
# 1   LATAM  Buenos Aires     Argentina         5111.04800
# 2  Europe        Burnie        France         4134.76500
# 3   LATAM     Santa Ana   El Salvador          495.18726
# 4   LATAM      Blumenau        Mexico         1758.91190
#
#                   order_date    order_id  order_item_cardprod_id  \
# 0  2015-08-12 00:00:00+01:00  15081.2890                   191.0
# 1  2017-02-10 00:00:00+00:00  56444.6840                  1073.0
# 2  2015-01-01 00:00:00+00:00   7508.5713                  1014.0
# 3  2017-05-31 00:00:00+01:00  56196.9260                   365.0
# 4  2015-03-28 00:00:00+00:00   5565.5796                  1073.0
#
#    order_item_discount  order_item_discount_rate  order_item_id  \
# 0            12.623338                      0.13      38030.996
# 1            16.500000                      0.07     142621.780
# 2             6.600000                      0.06      18723.178
# 3            16.942171                      0.16     141654.580
# 4            29.990000                      0.15      14204.896
#
#    order_item_product_price  order_item_profit_ratio  order_item_quantity  \
# 0                     99.99                     0.41                  1.0
# 1                    199.99                     0.48                  1.0
# 2                     49.98                     0.09                  2.0
# 3                     59.99                    -0.80                  2.0
# 4                    199.99                     0.27                  1.0
#
#     sales  order_item_total_amount  order_profit_per_order order_status  \
# 0   99.99                 84.99157               32.083145     COMPLETE
# 1  199.99                181.99000               91.235870      PENDING
# 2   99.96                 93.81015                6.965549     COMPLETE
# 3  119.98                 99.89060              -95.401400   PROCESSING
# 4  199.99                171.07587               44.569000     COMPLETE
#
#    product_card_id  product_category_id                       product_name  \
# 0            191.0                  9.0  Nike Men's Free 5.0+ Running Shoe
# 1           1073.0                 48.0        Pelican Sunstream 100 Kayak
# 2           1014.0                 46.0   O'Brien Men's Neoprene Life Vest
# 3            365.0                 17.0   Perfect Fitness Perfect Rip Deck
# 4           1073.0                 48.0        Pelican Sunstream 100 Kayak
#
#    product_price              shipping_date   shipping_mode  label
# 0          99.99  2015-08-13 00:00:00+01:00  Standard Class     -1
# 1         199.99  2017-04-09 00:00:00+01:00  Standard Class     -1
# 2          49.98  2015-03-18 00:00:00+00:00    Second Class      1
# 3          59.99  2017-03-18 00:00:00+00:00    Second Class      0
# 4         199.99  2015-03-30 00:00:00+01:00  Standard Class      1

# %%
# Convert order_date to datetime
data_log_1['order_date'] = pd.to_datetime(data_log_1['order_date'], errors='coerce', utc=True)

# Drop rows where conversion failed (NaT values)
data_log_1 = data_log_1.dropna(subset=['order_date'])

# First extract time before modifying order_date
data_log_1['order_time'] = data_log_1['order_date'].dt.time  # Extract time

# Now extract the date (this step changes order_date to object)
data_log_1['order_date_only'] = data_log_1['order_date'].dt.date  # Extract date

# Show results
print(data_log_1[['order_date', 'order_date_only', 'order_time']].head())
# Out:
#                  order_date order_date_only order_time
# 0 2015-08-11 23:00:00+00:00      2015-08-11   23:00:00
# 1 2017-02-10 00:00:00+00:00      2017-02-10   00:00:00
# 2 2015-01-01 00:00:00+00:00      2015-01-01   00:00:00
# 3 2017-05-30 23:00:00+00:00      2017-05-30   23:00:00
# 4 2015-03-28 00:00:00+00:00      2015-03-28   00:00:00

# %%
# Ensure the 'shipping_date' column is in datetime format with UTC option 
data_log_1['shipping_date'] = pd.to_datetime(data_log_1['shipping_date'], errors='coerce', utc=True)

# Drop rows where conversion failed (NaT values)
data_log_1 = data_log_1.dropna(subset=['shipping_date'])

# Now extract time before modifying shipping_date
data_log_1['shipping_time'] = data_log_1['shipping_date'].dt.time  # Extract time

# Now extract the date (this step changes shipping_date to object)
data_log_1['shipping_date_only'] = data_log_1['shipping_date'].dt.date  # Extract date

# Show results
print(data_log_1[['shipping_date', 'shipping_date_only', 'shipping_time']].head())
# Out:
#               shipping_date shipping_date_only shipping_time
# 0 2015-08-12 23:00:00+00:00         2015-08-12      23:00:00
# 1 2017-04-08 23:00:00+00:00         2017-04-08      23:00:00
# 2 2015-03-18 00:00:00+00:00         2015-03-18      00:00:00
# 3 2017-03-18 00:00:00+00:00         2017-03-18      00:00:00
# 4 2015-03-29 23:00:00+00:00         2015-03-29      23:00:00

# %%
display(data_log_1.head())
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city  customer_id customer_segment  \
# 0      Cardio Equipment        Caguas   12097.6830         Consumer
# 1          Water Sports   Albuquerque    5108.1045         Consumer
# 2  Indoor/Outdoor Games      Amarillo    4293.4478         Consumer
# 3                Cleats        Caguas     546.5306         Consumer
# 4          Water Sports       Peabody    1546.3980         Consumer
#
#    customer_zipcode  department_id department_name   latitude   longitude  \
# 0          725.0000            3.0        Footwear  18.359064  -66.370575
# 1        92745.1600            7.0        Fan Shop  37.636528 -121.119630
# 2         2457.7297            7.0        Fan Shop  18.294100  -66.037056
# 3          725.0000            4.0         Apparel  18.202435  -66.370510
# 4        95118.6000            7.0        Fan Shop  38.719500 -122.319720
#
#    market    order_city order_country  order_customer_id  \
# 0  Europe         Viena       Austria        12073.33600
# 1   LATAM  Buenos Aires     Argentina         5111.04800
# 2  Europe        Burnie        France         4134.76500
# 3   LATAM     Santa Ana   El Salvador          495.18726
# 4   LATAM      Blumenau        Mexico         1758.91190
#
#                  order_date    order_id  order_item_cardprod_id  \
# 0 2015-08-11 23:00:00+00:00  15081.2890                   191.0
# 1 2017-02-10 00:00:00+00:00  56444.6840                  1073.0
# 2 2015-01-01 00:00:00+00:00   7508.5713                  1014.0
# 3 2017-05-30 23:00:00+00:00  56196.9260                   365.0
# 4 2015-03-28 00:00:00+00:00   5565.5796                  1073.0
#
#    order_item_discount  order_item_discount_rate  order_item_id  \
# 0            12.623338                      0.13      38030.996
# 1            16.500000                      0.07     142621.780
# 2             6.600000                      0.06      18723.178
# 3            16.942171                      0.16     141654.580
# 4            29.990000                      0.15      14204.896
#
#    order_item_product_price  order_item_profit_ratio  order_item_quantity  \
# 0                     99.99                     0.41                  1.0
# 1                    199.99                     0.48                  1.0
# 2                     49.98                     0.09                  2.0
# 3                     59.99                    -0.80                  2.0
# 4                    199.99                     0.27                  1.0
#
#     sales  order_item_total_amount  order_profit_per_order order_status  \
# 0   99.99                 84.99157               32.083145     COMPLETE
# 1  199.99                181.99000               91.235870      PENDING
# 2   99.96                 93.81015                6.965549     COMPLETE
# 3  119.98                 99.89060              -95.401400   PROCESSING
# 4  199.99                171.07587               44.569000     COMPLETE
#
#    product_card_id  product_category_id                       product_name  \
# 0            191.0                  9.0  Nike Men's Free 5.0+ Running Shoe
# 1           1073.0                 48.0        Pelican Sunstream 100 Kayak
# 2           1014.0                 46.0   O'Brien Men's Neoprene Life Vest
# 3            365.0                 17.0   Perfect Fitness Perfect Rip Deck
# 4           1073.0                 48.0        Pelican Sunstream 100 Kayak
#
#    product_price             shipping_date   shipping_mode  label  \
# 0          99.99 2015-08-12 23:00:00+00:00  Standard Class     -1
# 1         199.99 2017-04-08 23:00:00+00:00  Standard Class     -1
# 2          49.98 2015-03-18 00:00:00+00:00    Second Class      1
# 3          59.99 2017-03-18 00:00:00+00:00    Second Class      0
# 4         199.99 2015-03-29 23:00:00+00:00  Standard Class      1
#
#   shipping_time shipping_date_only order_time order_date_only
# 0      23:00:00         2015-08-12   23:00:00      2015-08-11
# 1      23:00:00         2017-04-08   00:00:00      2017-02-10
# 2      00:00:00         2015-03-18   00:00:00      2015-01-01
# 3      00:00:00         2017-03-18   23:00:00      2017-05-30
# 4      23:00:00         2015-03-29   00:00:00      2015-03-28

# %%
# Save data_log_1 to CSV
#data_log_1.to_csv("../Data/income2024_cleaned.csv", index=False)
#print("data_log_1 saved to income2024_cleaned.csv")

# %%
# Dispalay file containing the description about the data 

file_path = "../Data/raw/incom2024_delay_variable_description.csv"

data_desc = pd.read_csv(file_path)
display(data_desc)
# Out:
#                variable_name         type  \
# 0               payment_type  categorical
# 1           profit_per_order    numerical
# 2         sales_per_customer    numerical
# 3                category_id    numerical
# 4              category_name         text
# 5              customer_city  categorical
# 6           customer_country  categorical
# 7                customer_id    numerical
# 8           customer_segment  categorical
# 9             customer_state  categorical
# 10          customer_zipcode         text
# 11             department_id    numerical
# 12           department_name         text
# 13                  latitude    numerical
# 14                 longitude    numerical
# 15                    market  categorical
# 16                order_city  categorical
# 17             order_country  categorical
# 18         order_customer_id    numerical
# 19                order_date     datetime
# 20                  order_id    numerical
# 21    order_item_cardprod_id    numerical
# 22       order_item_discount    numerical
# 23  order_item_discount_rate    numerical
# 24             order_item_id    numerical
# 25  order_item_product_price    numerical
# 26   order_item_profit_ratio    numerical
# 27       order_item_quantity    numerical
# 28                     sales    numerical
# 29   order_item_total_amount    numerical
# 30    order_profit_per_order    numerical
# 31              order_region  categorical
# 32               order_state  categorical
# 33              order_status  categorical
# 34           product_card_id    numerical
# 35       product_category_id    numerical
# 36              product_name         text
# 37             product_price    numerical
# 38             shipping_date     datetime
# 39             shipping_mode  categorical
# 40                     label  categorical
#
#                                           description
# 0                            Type of transaction made
# 1                           Earnings per order placed
# 2          Total sales per customer made per customer
# 3                               Product category code
# 4                 Description of the product category
# 5           City where the customer made the purchase
# 6        Country where the customer made the purchase
# 7                                         Customer ID
# 8   Types of Customers Consumer, Corporate, Home O...
# 9   State to which the store where the purchase is...
# 10                                   Customer Zipcode
# 11                           Department code of store
# 12                           Department name of store
# 13        Latitude corresponding to location of store
# 14       Longitude corresponding to location of store
# 15  Market to where the order is delivered: Africa...
# 16                      Destination city of the order
# 17                   Destination country of the order
# 18                                Customer order code
# 19                    Date on which the order is made
# 20                                         Order code
# 21     Product code generated through the RFID reader
# 22                          Order item discount value
# 23                     Order item discount percentage
# 24                                    Order item code
# 25                 Price of products without discount
# 26                            Order Item Profit Ratio
# 27                       Number of products per order
# 28                                     Value in sales
# 29                             Total amount per order
# 30                             Order Profit Per Order
# 31  Region of the world where the order is deliver...
# 32   State of the region where the order is delivered
# 33  Order Status: COMPLETE, PENDING, CLOSED, PENDI...
# 34                                       Product code
# 35                              Product category code
# 36                                       Product name
# 37                                      Product price
# 38                    Exact date and time of shipment
# 39  The following shipping modes are presented: St...
# 40  delivery outcomes: -1 early arrival, 0 on time...

# %%
data_log_1.columns # Standardizing columns
# Out:
# Index(['payment_type', 'profit_per_order', 'sales_per_customer', 'category_id',
#        'category_name', 'customer_city', 'customer_id', 'customer_segment',
#        'customer_zipcode', 'department_id', 'department_name', 'latitude',
#        'longitude', 'market', 'order_city', 'order_country',
#        'order_customer_id', 'order_date', 'order_id', 'order_item_cardprod_id',
#        'order_item_discount', 'order_item_discount_rate', 'order_item_id',
#        'order_item_product_price', 'order_item_profit_ratio',
#        'order_item_quantity', 'sales', 'order_item_total_amount',
#        'order_profit_per_order', 'order_status', 'product_card_id',
#        'product_category_id', 'product_name', 'product_price', 'shipping_date',
#        'shipping_mode', 'label', 'shipping_time', 'shipping_date_only',
#        'order_time', 'order_date_only'],
#       dtype='object')

# %%
data_log_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15549 entries, 0 to 15548
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   payment_type              15549 non-null  object
#  1   profit_per_order          15549 non-null  float64
#  2   sales_per_customer        15549 non-null  float64
#  3   category_id               15549 non-null  float64
#  4   category_name             15549 non-null  object
#  5   customer_city             15549 non-null  object
#  6   customer_id               15549 non-null  float64
#  7   customer_segment          15549 non-null  object
#  8   customer_zipcode          15549 non-null  float64
#  9   department_id             15549 non-null  float64
#  10  department_name           15549 non-null  object
#  11  latitude                  15549 non-null  float64
#  12  longitude                 15549 non-null  float64
#  13  market                    15549 non-null  object
#  14  order_city                15549 non-null  object
#  15  order_country             15549 non-null  object
#  16  order_customer_id         15549 non-null  float64
#  17  order_date                15549 non-null  datetime64[ns, UTC]
#  18  order_id                  15549 non-null  float64
#  19  order_item_cardprod_id    15549 non-null  float64
#  20  order_item_discount       15549 non-null  float64
#  21  order_item_discount_rate  15549 non-null  float64
#  22  order_item_id             15549 non-null  float64
#  23  order_item_product_price  15549 non-null  float64
#  24  order_item_profit_ratio   15549 non-null  float64
#  25  order_item_quantity       15549 non-null  float64
#  26  sales                     15549 non-null  float64
#  27  order_item_total_amount   15549 non-null  float64
#  28  order_profit_per_order    15549 non-null  float64
#  29  order_status              15549 non-null  object
#  30  product_card_id           15549 non-null  float64
#  31  product_category_id       15549 non-null  float64
#  32  product_name              15549 non-null  object
#  33  product_price             15549 non-null  float64
#  34  shipping_date             15549 non-null  datetime64[ns, UTC]
#  35  shipping_mode             15549 non-null  object
#  36  label                     15549 non-null  int64
#  37  shipping_time             15549 non-null  object
#  38  shipping_date_only        15549 non-null  object
#  39  order_time                15549 non-null  object
#  40  order_date_only           15549 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(23), int64(1), object(15)
# memory usage: 4.9+ MB

# %%
data_log_1.isnull().sum()
# Out:
# payment_type                0
# profit_per_order            0
# sales_per_customer          0
# category_id                 0
# category_name               0
# customer_city               0
# customer_id                 0
# customer_segment            0
# customer_zipcode            0
# department_id               0
# department_name             0
# latitude                    0
# longitude                   0
# market                      0
# order_city                  0
# order_country               0
# order_customer_id           0
# order_date                  0
# order_id                    0
# order_item_cardprod_id      0
# order_item_discount         0
# order_item_discount_rate    0
# order_item_id               0
# order_item_product_price    0
# order_item_profit_ratio     0
# order_item_quantity         0
# sales                       0
# order_item_total_amount     0
# order_profit_per_order      0
# order_status                0
# product_card_id             0
# product_category_id         0
# product_name                0
# product_price               0
# shipping_date               0
# shipping_mode               0
# label                       0
# shipping_time               0
# shipping_date_only          0
# order_time                  0
# order_date_only             0
# dtype: int64

# %% [markdown]
# ## UNIVARIATE ANALYSIS ##

# %%
#Separate numerical and categorical columns
num_cols = data_log_1.select_dtypes(include=['float64', 'int64']).columns
cat_cols = data_log_1.select_dtypes(include=['object']).columns

# %%
# Summary statistics for numerical data
print("\nSummary statistics for numerical data: ")
display(data_log_1[num_cols].describe())

# %%
#Value counts for categorical data
print("\nValue counts for categorical data: ")
for col in cat_cols: 
    print(f"\n{col}:\n", data_log_1[col].value_counts())

# %% [markdown]
# ## Visualization

# %%
# Histogram for numerical features
# Histograms for numerical features
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(data_log_1[col], bins=30, kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
#Boxplots for numerical features: check for outliers
for col in num_cols:
    plt.figure9figsize=(10, 6)
    sns.boxplot(x=data_log_1[col])
    plt.title(f"{col}")
    plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(10, 5))
    data_log_1[col].value_counts().nlargest(10).plot(kind='bar', color='skyblue')
    plt.title(f"{col}")
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Bivariate Analysis ##
